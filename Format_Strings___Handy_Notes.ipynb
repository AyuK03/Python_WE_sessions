# %% [markdown]
# <a href="https://colab.research.google.com/github/AyuK03/Python_WE_sessions/blob/main/Format_Strings___Handy_Notes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Method 1**: Formatting string using % Operator.
#
# It is the oldest method of string formatting. Here we use the modulo % operator. The modulo % is also known as the “string-formatting operator”.

# %%
print("The mangy, scrawny stray dog %s gobbled down" %'hurriedly' +
	"the grain-free, organic dog food.")
# Out:
# The mangy, scrawny stray dog hurriedly gobbled downthe grain-free, organic dog food.

# %% [markdown]
# Example 2: Injecting multiple strings using % operator

# %%
x = 'looked'

print("Misha %s and %s around"%('walked',x))
# Out:
# Misha walked and looked around

# %% [markdown]
# ‘%s’ is used to inject strings similarly ‘%d’ for integers, ‘%f’ for floating-point values, ‘%b’ for binary format.

# %%
print('Joe stood up and %s to the crowd.' %'spoke')

print('There are %d dogs.' %4)

print('The value of pi is: %5.4f' %(3.141592))             # DOUBT : what does 5 in %5.4f represent ?
print('Floating point numbers: %0.4f' %(13.144))
print('Floating point numbers: %1.0f' %(13.5666))

# %6.2f :- means output will be in 6 columns and .2 signifies no. of decimal points
# Out:
# Joe stood up and spoke to the crowd.
# There are 4 dogs.
# The value of pi is: 3.1416
# Floating point numbers: 13.1440
# Floating point numbers: 14

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
#
# # https://codzify.com/article/C/formatSpecifiers

# %%
variable = 12

string = "Variable as integer = %d \n\
Variable as float = %f" %(variable, variable)

print (string)

# %% [markdown]
# **Method 2:** Formatting string using format() method

# %% [markdown]
# Syntax: ‘String here {} then also {}’.format(‘something1′,’something2’)

# %%
print('We all are {}.'.format('equal'))

# We can insert object by using index-based position:

print('{2} {1} {0}'.format('directions',
						'the', 'Read'))

# We can insert objects by using assigned keywords:

print('a: {a}, b: {b}, c: {c}'.format(a = 1,
									b = 'Two',
									c = 12.3))

# %% [markdown]
# **Float precision with the.format() method:**
#
# Syntax: { [index] : [width] [.precision] [type] }
#
# The type can be used with format codes:
#
# ‘d’ for integers
#
# ‘f’ for floating-point numbers
#
# ‘b’ for binary numbers
#
# ‘o’ for octal numbers
#
# ‘x’ for octal hexadecimal numbers
#
# ‘s’ for string
#
# ‘e’ for floating-point in an exponent format

# %%
print('The valueof pi is: %1.5f' %3.141592)

# vs.

print('The valueof pi is: {0:1.5f}'.format(3.141592))

# %% [markdown]
# **Method 3:** Formatted String using F-strings

# %%
name = 'Ele'

print(f"My name is {name}.")

a = 5

b = 10

print(f"He said his age is {2 * (a + b)}.")

# We can also use lambda expressions in f-string formatting.

print(f"He said his age is {(lambda x: x*2)(3)}")
# Out:
# My name is Ele.

# %% [markdown]
# ![image.png](data:image/png;base64,...)![image.png]()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
