# %% [markdown]
# <a href="https://colab.research.google.com/github/AyuK03/Python_WE_sessions/blob/main/map_filter_reduce_lambda_zip_AggregateFunctions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def power_of_5(x):
    return x ** 5

a = [1, 2, 3, 4, 5]
result = map(power_of_5, a)
print(list(result))
# Out:
# [1, 32, 243, 1024, 3125]

# %%
#filter(function, iterable)
def isOdd(x):
    if x % 2 == 1:
        return True

a = [1, 2, 3, 45, 67, 88, 97, 456]
odd = filter(isOdd, a)
print(odd)
print(list(odd))
# Out:
# ...
# [1, 3, 45, 67, 97]

# %%
#reduce()
#functools module
#functools.reduce(function, iterable)
#Calcute the product of a list.
from functools import reduce
def multiplication(x, y):
    return x * y

a = [1, 2, 3, 4, 5, 6, 7, 8, 9]
result = reduce(multiplication, a)
print(result)
# Out:
# 362880

# %%
a = [121,555,63,636]
result = list(filter(lambda x: (x == int("".join(reversed(str(x))))), a)) 
print(result)
# Out:
# [121, 555, 636]

# %%
(lambda x: (x == "".join(reversed(x))))("madam")
# Out:
# True

# %%
(lambda x: (x == "".join(reversed(x))))("121")
# Out:
# True

# %% [markdown]
# # lambda function : anonymous function
#
# lambda parameters : expression
#
# **lambda is an expression —>**
#
# The value of the expression is returned.
#
# Only an expression can be the body

# %%
# Qn . Add 3 numbers

add = lambda x,y,z: x+y+z

# %%
add(23,56,78)
# Out:
# 157

# %%
# Check if number is greater than 1,then return number, else return -1

res = lambda a: a if a>10 else -1

res(23)    # inspecting
res(3.5)   # printing

# Note only the last call is in the output ... as return statement is executed only once
# But we can get each called value as output by printing every time we call the lambda function
# Out:
# -1

# %%
print(res(23))
print(res(3.5))
# Out:
# 23
# -1

# %%
# Return num * 10 if num > 10, return x * 5 if num < 5 otherwise return num

result = lambda num: num * 10 if num > 10 else (num*5 if num < 5 else num)

# %%
print(result(11))
print(result(2))
print(result(6))
# Out:
# 110
# 10
# 6

# %%
a = "Hello"

# %% [markdown]
# If we inspect multiple statements, only the latest statement inspection will be displayed as an output

# %%
a
# Out:
# 'Hello'

# %% [markdown]
# Inspection returns value in quotes
#
# Printing returns value without quotes

# %%
print(a)
# Out:
# Hello

# %%
numbers = [11, 12, 13, 14, 15, 16, 17, 18, 19]

# %% [markdown]
# # zip function
#
# zip (*iterables) - one or more iterables

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
L1 = [1, 2, 3, 4, 5]
L2 = [6, 7, 8, 9, 10]

output = zip(L1,L2)

print(output)
print(list(output))
# Out:
# ...
# [(1, 6), (2, 7), (3, 8), (4, 9), (5, 10)]

# %%
x = [1, 2, 3, 4, 5]
y = ['a', 'b', 'c', 'd', 'e']

result = zip(x,y)

print(list(result))
# Out:
# [(1, 'a'), (2, 'b'), (3, 'c'), (4, 'd'), (5, 'e')]

# %%
x = [1, 2, 3, 4, 5]

result = zip(x)
print(list(result))
# Out:
# [(1,), (2,), (3,), (4,), (5,)]

# %%
m = [1, 3, 50, 23]
n = ['a', 'm']

ans = zip(m,n)

print(ans)

print(list(ans))
# Out:
# ...
# [(1, 'a'), (3, 'm')]

# %% [markdown]
# Q. Multiply corresponding elements of 2 given lists

# %%
a = [ 1, 2, 3, 4, 5 ]
b = [ 10, 20, 30, 40, 50 ]

product = [x * y for x,y in zip(a,b)]
print(product)
# Out:
# [10, 40, 90, 160, 250]

# %% [markdown]
# # Aggregate Functions

# %%
sales = [100, 200, 300]

total_sales = sum(sales)

print(total_sales)
# Out:
# 600

# %%
print(max(sales), min(sales))
# Out:
# 300 100

# %%
x = [23, 90, 12, 9, 100, 20, 1]

print(sorted(x))
# Out:
# [1, 9, 12, 20, 23, 90, 100]

# %% [markdown]
# # Extended Boolean Functions
#
# all(iterable), any(iterable)

# %%
x = [ 2>3, 5<7, False, "Hi" == "Python"]

print(all(x))
print(any(x))
# Out:
# False
# True

# %% [markdown]
# # Mathematical Functions

# %%
print(abs(-4.78))
# Out:
# 4.78

# %%
print(pow(5,2))
# Out:
# 25

# %%
print(round(4.26))
print(round(9.5))
print(round(8.5))    # CONCEPT : even digit( here 8 ) before digit 5

print(round(24.69256,3))    # DOUBT
# Out:
# 4
# 10
# 8
# 24.693

# %%
print(divmod(7,3))
# Out:
# (2, 1)

# %% [markdown]
# # Converters
#
# **Converters** example : int(), float(), str(), bool(), list(), tuple(), dict(), bin()

# %%
num_str = "123"

print(type(num_str))
# Out:
# <class 'str'>

# %%
num = int(num_str)
print(type(num))
# Out:
# <class 'int'>

# %%
print(bin(10))
print(bool(0))
print(bool(23))
# Out:
# 0b1010
# False
# True

# %%
print(chr(97))     # ASCII value passed
# Out:
# a

# %%
print(ord('K'))
# Out:
# 75

# %%
print(complex(3,8))
# Out:
# (3+8j)

# %%
float(9)
# Out:
# 9.0

# %%
print(hex(34))
# Out:
# 0x22

# %%
print(oct(67))
# Out:
# 0o103

# %%
print(set("Hello"))
# Out:
# {'l', 'e', 'o', 'H'}

# %%
str(1234)
# Out:
# '1234'

# %%
print(tuple("hello"))
# Out:
# ('h', 'e', 'l', 'l', 'o')
